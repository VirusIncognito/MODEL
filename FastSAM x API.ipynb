# %%
# !pip install matplotlib>=3.2.2
# !pip install opencv-python>=4.6.0
# !pip install Pillow>=7.1.2
# !pip install PyYAML>=5.3.1
# !pip install requests>=2.23.0
# !pip install scipy>=1.4.1
# !pip install torch>=1.7.0
# !pip install torchvision>=0.8.1
# !pip install tqdm>=4.64.0

# !pip install pandas>=1.1.4
# !pip install seaborn>=0.11.0

# !pip install gradio==3.35.2
# Out:
# Requirement already satisfied: gradio==3.35.2 in c:\users\kiit\anaconda3\lib\site-packages (3.35.2)
# Requirement already satisfied: aiofiles in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (22.1.0)
# Requirement already satisfied: aiohttp in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (3.9.5)
# Requirement already satisfied: altair>=4.2.0 in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (5.0.1)
# Requirement already satisfied: fastapi in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (0.111.0)
# Requirement already satisfied: ffmpy in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (0.3.2)
# Requirement already satisfied: gradio-client>=0.2.7 in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (0.16.4)
# Requirement already satisfied: httpx in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (0.26.0)
# Requirement already satisfied: huggingface-hub>=0.14.0 in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (0.20.3)
# Requirement already satisfied: jinja2 in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.0.0 in c:\users\kiit\anaconda3\lib\site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.35.2) (2.2.0)
# Requirement already satisfied: markupsafe in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (2.1.3)
# Requirement already satisfied: matplotlib in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (3.8.4)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (0.3.0)
# Requirement already satisfied: numpy in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (1.23.5)
# Requirement already satisfied: orjson in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (3.10.3)
# Requirement already satisfied: pandas in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (2.2.1)
# Requirement already satisfied: pillow in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (10.3.0)
# Requirement already satisfied: pydantic in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (2.5.3)
# Requirement already satisfied: pydub in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (0.25.1)
# Requirement already satisfied: pygments>=2.12.0 in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (2.15.1)
# Requirement already satisfied: python-multipart in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (0.0.9)
# Requirement already satisfied: pyyaml in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (6.0.1)
# Requirement already satisfied: requests in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (2.31.0)
# Requirement already satisfied: semantic-version in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (2.10.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (0.29.0)
# Requirement already satisfied: websockets>=10.0 in c:\users\kiit\anaconda3\lib\site-packages (from gradio==3.35.2) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\kiit\anaconda3\lib\site-packages (from altair>=4.2.0->gradio==3.35.2) (4.19.2)
# Requirement already satisfied: toolz in c:\users\kiit\anaconda3\lib\site-packages (from altair>=4.2.0->gradio==3.35.2) (0.12.0)
# Requirement already satisfied: fsspec in c:\users\kiit\anaconda3\lib\site-packages (from gradio-client>=0.2.7->gradio==3.35.2) (2023.10.0)
# Requirement already satisfied: packaging in c:\users\kiit\anaconda3\lib\site-packages (from gradio-client>=0.2.7->gradio==3.35.2) (23.2)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\kiit\anaconda3\lib\site-packages (from gradio-client>=0.2.7->gradio==3.35.2) (4.11.0)
# Requirement already satisfied: anyio in c:\users\kiit\anaconda3\lib\site-packages (from httpx->gradio==3.35.2) (4.2.0)
# Requirement already satisfied: certifi in c:\users\kiit\anaconda3\lib\site-packages (from httpx->gradio==3.35.2) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\kiit\anaconda3\lib\site-packages (from httpx->gradio==3.35.2) (1.0.2)
# Requirement already satisfied: idna in c:\users\kiit\anaconda3\lib\site-packages (from httpx->gradio==3.35.2) (3.7)
# Requirement already satisfied: sniffio in c:\users\kiit\anaconda3\lib\site-packages (from httpx->gradio==3.35.2) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\kiit\anaconda3\lib\site-packages (from httpcore==1.*->httpx->gradio==3.35.2) (0.14.0)
# Requirement already satisfied: filelock in c:\users\kiit\anaconda3\lib\site-packages (from huggingface-hub>=0.14.0->gradio==3.35.2) (3.13.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\kiit\anaconda3\lib\site-packages (from huggingface-hub>=0.14.0->gradio==3.35.2) (4.66.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kiit\anaconda3\lib\site-packages (from markdown-it-py>=2.0.0->markdown-it-py[linkify]>=2.0.0->gradio==3.35.2) (0.1.0)
# Requirement already satisfied: linkify-it-py<3,>=1 in c:\users\kiit\anaconda3\lib\site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.35.2) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kiit\anaconda3\lib\site-packages (from pandas->gradio==3.35.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kiit\anaconda3\lib\site-packages (from pandas->gradio==3.35.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kiit\anaconda3\lib\site-packages (from pandas->gradio==3.35.2) (2023.3)
# Requirement already satisfied: click>=7.0 in c:\users\kiit\anaconda3\lib\site-packages (from uvicorn>=0.14.0->gradio==3.35.2) (8.1.7)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kiit\anaconda3\lib\site-packages (from aiohttp->gradio==3.35.2) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kiit\anaconda3\lib\site-packages (from aiohttp->gradio==3.35.2) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kiit\anaconda3\lib\site-packages (from aiohttp->gradio==3.35.2) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kiit\anaconda3\lib\site-packages (from aiohttp->gradio==3.35.2) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\kiit\anaconda3\lib\site-packages (from aiohttp->gradio==3.35.2) (1.9.3)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\kiit\anaconda3\lib\site-packages (from fastapi->gradio==3.35.2) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\kiit\anaconda3\lib\site-packages (from fastapi->gradio==3.35.2) (0.0.4)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\kiit\anaconda3\lib\site-packages (from fastapi->gradio==3.35.2) (5.4.0)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\kiit\anaconda3\lib\site-packages (from fastapi->gradio==3.35.2) (2.1.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\kiit\anaconda3\lib\site-packages (from pydantic->gradio==3.35.2) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\kiit\anaconda3\lib\site-packages (from pydantic->gradio==3.35.2) (2.14.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib->gradio==3.35.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib->gradio==3.35.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib->gradio==3.35.2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib->gradio==3.35.2) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib->gradio==3.35.2) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kiit\anaconda3\lib\site-packages (from requests->gradio==3.35.2) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kiit\anaconda3\lib\site-packages (from requests->gradio==3.35.2) (2.2.1)
# Requirement already satisfied: colorama in c:\users\kiit\anaconda3\lib\site-packages (from click>=7.0->uvicorn>=0.14.0->gradio==3.35.2) (0.4.6)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\kiit\anaconda3\lib\site-packages (from email_validator>=2.0.0->fastapi->gradio==3.35.2) (2.6.1)
# Requirement already satisfied: typer>=0.12.3 in c:\users\kiit\anaconda3\lib\site-packages (from fastapi-cli>=0.0.2->fastapi->gradio==3.35.2) (0.12.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\kiit\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.35.2) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\kiit\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.35.2) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\kiit\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.35.2) (0.10.6)
# Requirement already satisfied: uc-micro-py in c:\users\kiit\anaconda3\lib\site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio==3.35.2) (1.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\kiit\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->gradio==3.35.2) (1.16.0)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\kiit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio==3.35.2) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\kiit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio==3.35.2) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\kiit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio==3.35.2) (0.21.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\kiit\anaconda3\lib\site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->gradio==3.35.2) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\kiit\anaconda3\lib\site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->gradio==3.35.2) (13.3.5)

# %%
#@title Install requirements
from io import BytesIO
import IPython
import json
import os
from PIL import Image
import requests
import time
from google.colab import output
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 9
#       7 import requests
#       8 import time
# ----> 9 from google.colab import output
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
#@title Connect to the Stability API

import getpass8.0
# @markdown To get your API key visit https://platform.stability.ai/account/keys
STABILITY_KEY = getpass.getpass('Enter your API Key')
# Out:
# Enter your API Key········

# %%
#@title Define functions

def send_generation_request(
    host,
    params,
):
    headers = {
        "Accept": "image/*",
        "Authorization": f"Bearer {STABILITY_KEY}"
    }

    # Encode parameters
    files = {}
    image = params.pop("image", None)
    mask = params.pop("mask", None)
    if image is not None and image != '':
        files["image"] = open(image, 'rb')
    if mask is not None and mask != '':
        files["mask"] = open(mask, 'rb')
    if len(files)==0:
        files["none"] = ''

    # Send request
    print(f"Sending REST request to {host}...")
    response = requests.post(
        host,
        headers=headers,
        files=files,
        data=params
    )
    if not response.ok:
        raise Exception(f"HTTP {response.status_code}: {response.text}")

    return response

def send_async_generation_request(
    host,
    params,
):
    headers = {
        "Accept": "application/json",
        "Authorization": f"Bearer {STABILITY_KEY}"
    }

    # Encode parameters
    files = {}
    if "image" in params:
        image = params.pop("image")
        files = {"image": open(image, 'rb')}

    # Send request
    print(f"Sending REST request to {host}...")
    response = requests.post(
        host,
        headers=headers,
        files=files,
        data=params
    )
    if not response.ok:
        raise Exception(f"HTTP {response.status_code}: {response.text}")

    # Process async response
    response_dict = json.loads(response.text)
    generation_id = response_dict.get("id", None)
    assert generation_id is not None, "Expected id in response"

    # Loop until result or timeout
    timeout = int(os.getenv("WORKER_TIMEOUT", 500))
    start = time.time()
    status_code = 202
    while status_code == 202:
        response = requests.get(
            f"{host}/result/{generation_id}",
            headers={
                **headers,
                "Accept": "image/*"
            },
        )

        if not response.ok:
            raise Exception(f"HTTP {response.status_code}: {response.text}")
        status_code = response.status_code
        time.sleep(10)
        if time.time() - start > timeout:
            raise Exception(f"Timeout after {timeout} seconds")

    return response

# %%
import fsam.Inference as inference
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import fsam.Inference as inference
#
# File ~\Desktop\BITS Pilani Research Docs\MODEL\fsam\Inference.py:4
#       2 import torch
#       3 from PIL import Image
# ----> 4 from fastsam import FastSAM, FastSAMPrompt
#       5 from utils.tools import convert_box_xywh_to_xyxy
#       8 def get_predefined_input(image, text_prompt):
#
# File ~\Desktop\BITS Pilani Research Docs\MODEL\fsam\fastsam\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from .model import FastSAM
#       4 from .predict import FastSAMPredictor
#       5 from .prompt import FastSAMPrompt
#
# File ~\Desktop\BITS Pilani Research Docs\MODEL\fsam\fastsam\model.py:12
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       2 """
#       3 FastSAM model interface.
#       4
#    (...)
#       9     results = model.predict('ultralytics/assets/bus.jpg')
#      10 """
# ---> 12 from ultralytics.yolo.cfg import get_cfg
#      13 from ultralytics.yolo.engine.exporter import Exporter
#      14 from ultralytics.yolo.engine.model import YOLO
#
# File ~\anaconda3\Lib\site-packages\ultralytics\__init__.py:5
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       3 __version__ = '8.0.120'
# ----> 5 from ultralytics.hub import start
#       6 from ultralytics.vit.rtdetr import RTDETR
#       7 from ultralytics.vit.sam import SAM
#
# File ~\anaconda3\Lib\site-packages\ultralytics\hub\__init__.py:5
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       3 import requests
# ----> 5 from ultralytics.hub.auth import Auth
#       6 from ultralytics.hub.utils import PREFIX
#       7 from ultralytics.yolo.data.utils import HUBDatasetStats
#
# File ~\anaconda3\Lib\site-packages\ultralytics\hub\auth.py:5
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       3 import requests
# ----> 5 from ultralytics.hub.utils import HUB_API_ROOT, PREFIX, request_with_credentials
#       6 from ultralytics.yolo.utils import LOGGER, SETTINGS, emojis, is_colab, set_settings
#       8 API_KEY_URL = 'https://hub.ultralytics.com/settings?tab=api+keys'
#
# File ~\anaconda3\Lib\site-packages\ultralytics\hub\utils.py:14
#      11 import requests
#      12 from tqdm import tqdm
# ---> 14 from ultralytics.yolo.utils import (ENVIRONMENT, LOGGER, ONLINE, RANK, SETTINGS, TESTS_RUNNING, TQDM_BAR_FORMAT,
#      15                                     TryExcept, __version__, colorstr, get_git_origin_url, is_colab, is_git_dir,
#      16                                     is_pip_package)
#      18 PREFIX = colorstr('Ultralytics HUB: ')
#      19 HELP_MSG = 'If this issue persists please visit https://github.com/ultralytics/hub/issues for assistance.'
#
# File ~\anaconda3\Lib\site-packages\ultralytics\yolo\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from . import v8
#       5 __all__ = 'v8',
#
# File ~\anaconda3\Lib\site-packages\ultralytics\yolo\v8\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from ultralytics.yolo.v8 import classify, detect, pose, segment
#       5 __all__ = 'classify', 'segment', 'detect', 'pose'
#
# File ~\anaconda3\Lib\site-packages\ultralytics\yolo\v8\classify\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from ultralytics.yolo.v8.classify.predict import ClassificationPredictor, predict
#       4 from ultralytics.yolo.v8.classify.train import ClassificationTrainer, train
#       5 from ultralytics.yolo.v8.classify.val import ClassificationValidator, val
#
# File ~\anaconda3\Lib\site-packages\ultralytics\yolo\v8\classify\predict.py:5
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       3 import torch
# ----> 5 from ultralytics.yolo.engine.predictor import BasePredictor
#       6 from ultralytics.yolo.engine.results import Results
#       7 from ultralytics.yolo.utils import DEFAULT_CFG, ROOT
#
# File ~\anaconda3\Lib\site-packages\ultralytics\yolo\engine\predictor.py:37
#      34 import numpy as np
#      35 import torch
# ---> 37 from ultralytics.nn.autobackend import AutoBackend
#      38 from ultralytics.yolo.cfg import get_cfg
#      39 from ultralytics.yolo.data import load_inference_source
#
# File ~\anaconda3\Lib\site-packages\ultralytics\nn\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from .tasks import (BaseModel, ClassificationModel, DetectionModel, SegmentationModel, attempt_load_one_weight,
#       4                     attempt_load_weights, guess_model_scale, guess_model_task, parse_model, torch_safe_load,
#       5                     yaml_model_load)
#       7 __all__ = ('attempt_load_one_weight', 'attempt_load_weights', 'parse_model', 'yaml_model_load', 'guess_model_task',
#       8            'guess_model_scale', 'torch_safe_load', 'DetectionModel', 'SegmentationModel', 'ClassificationModel',
#       9            'BaseModel')
#
# File ~\anaconda3\Lib\site-packages\ultralytics\nn\tasks.py:10
#       7 import torch
#       8 import torch.nn as nn
# ---> 10 from ultralytics.nn.modules import (AIFI, C1, C2, C3, C3TR, SPP, SPPF, Bottleneck, BottleneckCSP, C2f, C3Ghost, C3x,
#      11                                     Classify, Concat, Conv, Conv2, ConvTranspose, Detect, DWConv, DWConvTranspose2d,
#      12                                     Focus, GhostBottleneck, GhostConv, HGBlock, HGStem, Pose, RepC3, RepConv,
#      13                                     RTDETRDecoder, Segment)
#      14 from ultralytics.yolo.utils import DEFAULT_CFG_DICT, DEFAULT_CFG_KEYS, LOGGER, colorstr, emojis, yaml_load
#      15 from ultralytics.yolo.utils.checks import check_requirements, check_suffix, check_yaml
#
# File ~\anaconda3\Lib\site-packages\ultralytics\nn\modules\__init__.py:20
#      16 from .block import (C1, C2, C3, C3TR, DFL, SPP, SPPF, Bottleneck, BottleneckCSP, C2f, C3Ghost, C3x, GhostBottleneck,
#      17                     HGBlock, HGStem, Proto, RepC3)
#      18 from .conv import (CBAM, ChannelAttention, Concat, Conv, Conv2, ConvTranspose, DWConv, DWConvTranspose2d, Focus,
#      19                    GhostConv, LightConv, RepConv, SpatialAttention)
# ---> 20 from .head import Classify, Detect, Pose, RTDETRDecoder, Segment
#      21 from .transformer import (AIFI, MLP, DeformableTransformerDecoder, DeformableTransformerDecoderLayer, LayerNorm2d,
#      22                           MLPBlock, MSDeformAttn, TransformerBlock, TransformerEncoderLayer, TransformerLayer)
#      24 __all__ = ('Conv', 'Conv2', 'LightConv', 'RepConv', 'DWConv', 'DWConvTranspose2d', 'ConvTranspose', 'Focus',
#      25            'GhostConv', 'ChannelAttention', 'SpatialAttention', 'CBAM', 'Concat', 'TransformerLayer',
#      26            'TransformerBlock', 'MLPBlock', 'LayerNorm2d', 'DFL', 'HGBlock', 'HGStem', 'SPP', 'SPPF', 'C1', 'C2', 'C3',
#      27            'C2f', 'C3x', 'C3TR', 'C3Ghost', 'GhostBottleneck', 'Bottleneck', 'BottleneckCSP', 'Proto', 'Detect',
#      28            'Segment', 'Pose', 'Classify', 'TransformerEncoderLayer', 'RepC3', 'RTDETRDecoder', 'AIFI',
#      29            'DeformableTransformerDecoder', 'DeformableTransformerDecoderLayer', 'MSDeformAttn', 'MLP')
#
# File ~\anaconda3\Lib\site-packages\ultralytics\nn\modules\head.py:12
#       9 import torch.nn as nn
#      10 from torch.nn.init import constant_, xavier_uniform_
# ---> 12 from ultralytics.yolo.utils.tal import dist2bbox, make_anchors
#      14 from .block import DFL, Proto
#      15 from .conv import Conv
#
# File ~\anaconda3\Lib\site-packages\ultralytics\yolo\utils\__init__.py:766
#     762 # Run below code on yolo/utils init ------------------------------------------------------------------------------------
#     763
#     764 # Check first-install steps
#     765 PREFIX = colorstr('Ultralytics: ')
# --> 766 SETTINGS = get_settings()
#     767 DATASETS_DIR = Path(SETTINGS['datasets_dir'])  # global datasets directory
#     768 ENVIRONMENT = 'Colab' if is_colab() else 'Kaggle' if is_kaggle() else 'Jupyter' if is_jupyter() else \
#     769     'Docker' if is_docker() else platform.system()
#
# File ~\anaconda3\Lib\site-packages\ultralytics\yolo\utils\__init__.py:699, in get_settings(file, version)
#     696 import hashlib
#     698 from ultralytics.yolo.utils.checks import check_version
# --> 699 from ultralytics.yolo.utils.torch_utils import torch_distributed_zero_first
#     701 git_dir = get_git_dir()
#     702 root = git_dir or Path()
#
# File ~\anaconda3\Lib\site-packages\ultralytics\yolo\utils\torch_utils.py:18
#      16 import torch.nn as nn
#      17 import torch.nn.functional as F
# ---> 18 import torchvision
#      20 from ultralytics.yolo.utils import DEFAULT_CFG_DICT, DEFAULT_CFG_KEYS, LOGGER, RANK, __version__
#      21 from ultralytics.yolo.utils.checks import check_version
#
# File ~\anaconda3\Lib\site-packages\torchvision\__init__.py:6
#       3 from modulefinder import Module
#       5 import torch
# ----> 6 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils
#       8 from .extension import _HAS_OPS
#      10 try:
#
# File ~\anaconda3\Lib\site-packages\torchvision\_meta_registrations.py:4
#       1 import functools
#       3 import torch
# ----> 4 import torch._custom_ops
#       5 import torch.library
#       7 # Ensure that torch.ops.torchvision is visible
#
# File ~\anaconda3\Lib\site-packages\torch\_custom_ops.py:10
#       1 import inspect
#       3 from torch._custom_op.impl import (
#       4     _custom_op_with_schema,
#       5     _find_custom_op,
#    (...)
#       8     validate_namespace,
#       9 )
# ---> 10 from torch.library import get_ctx
#      12 __all__ = [
#      13     "custom_op",
#      14     "impl",
#    (...)
#      18     "impl_backward",
#      19 ]
#      22 def custom_op(qualname, func_or_schema=None):
#
# ImportError: cannot import name 'get_ctx' from 'torch.library' (C:\Users\KIIT\anaconda3\Lib\site-packages\torch\library.py)

# %%
image = "" #@param {type:"string"}
prompt = "artificer of time and space" #@param {type:"string"}
negative_prompt = "" #@param {type:"string"}
seed = 0 #@param {type:"integer"}
output_format = "webp" #@param ["webp", "jpeg", "png"]

inference.get_user_input(image, prompt)
mask = "./FastSAM/output/" #@param {type:"string"}

# %%
#@title Inpaint

#@markdown - Drag and drop image to file folder on left
#@markdown - Right click it and choose Copy path
#@markdown - Paste that path into image field below
#@markdown <br><br>


host = f"https://api.stability.ai/v2beta/stable-image/edit/inpaint"

params = {
    "image" : image,
    "mask" : mask,
    "negative_prompt" : negative_prompt,
    "seed" : seed,
    "mode": "mask",
    "output_format": output_format,
    "prompt" : prompt
}

response = send_generation_request(
    host,
    params
)

# Decode response
output_image = response.content
finish_reason = response.headers.get("finish-reason")
seed = response.headers.get("seed")

# Check for NSFW classification
if finish_reason == 'CONTENT_FILTERED':
    raise Warning("Generation failed NSFW classifier")

# Save and display result
filename, _ = os.path.splitext(os.path.basename(image))
edited = f"edited_{filename}_{seed}.{output_format}"
with open(edited, "wb") as f:
    f.write(output_image)
print(f"Saved image {edited}")

output.no_vertical_scroll()
print("Original image:")
IPython.display.display(Image.open(image))
print("Result image:")
IPython.display.display(Image.open(edited))
